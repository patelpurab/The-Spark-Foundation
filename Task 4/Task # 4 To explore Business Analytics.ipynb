# %% [markdown]
# # Task 4: To explore Business Analytics

# %% [markdown]
# In this notebook I am going to perform ‘Exploratory Data Analysis’ on the provided dataset 'SampleSuperstore'.

# %% [markdown]
# # ‘Exploratory Data Analysis’

# %% [markdown]
# **Problem Statement:**
# Suppose, You are the business owner of the retail firm and want to see how your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data? You can choose any of the tool of your choice like Python/R/"PowerBI/Excel.

# %% [markdown]
# **Author:** *Purab Patel*

# %% [markdown]
# ### Importing some required python libraries

# %%
import numpy as np # array operations
import pandas as pd # data analysis
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization
# %matplotlib inline

# %% [markdown]
# ### Loading the dataset

# %%
data = pd.read_csv("SampleSuperstore.csv") # pandas function

# %% [markdown]
# ### Exploring dataset

# %%
data.head() # by deafult head() takes top 5 rows from dataset
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail() # by default .tail() method taks bottom 5 rows from dataset
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.shape # getting no. of rows and columns in a detaset as tuple form
# Out:
# (9994, 13)

# %% [markdown]
# *here, are 9994 rows and 13 coumns*

# %%
data.columns # getting each colummn names of datsets
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe() # getting statistical infortation of dataset
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info() # getting fundamental/basic information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.isnull().sum() # checking null values in the dataset
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# *here, there is no null values in the dataset*

# %%
data.duplicated().sum() # checking duplicate values in the dataset
# Out:
# 17

# %% [markdown]
# *here, there are total 17 duplicates values in the dataset*

# %%
data.drop_duplicates(inplace=True) # so removing duplicates values form dataset

# %%
data.shape # now checking rows of dataset it must be less 17 than before
# Out:
# (9977, 13)

# %% [markdown]
# *ya, that correct!*

# %% [markdown]
# ### Correlating the dataset
# - To see how the feature values are correlated to each other.

# %%
corr_data = data.corr()

# %%
corr_data
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# ### Now, Plotting a heat map of our correlated data
# - A heat map is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions.
# The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %%
sns.set()
plt.figure(figsize = (15, 12))
sns.heatmap(data.corr(),annot= True, lw=8, cmap="pink", linecolor="m") # m for magneta

# %% [markdown]
# ### Now, Plotting the pairplot
# - It is really a simple way (as we can write it in single line code) to visualize relationships between each variable.
# - It produces a matrix of relationships between each variable in data for an instant examination of our data.

# %%
sns.pairplot(data)

# %% [markdown]
# ### Pre-processing Pipeline
# - Pipelines are a simple way to keep your data preprocessing and modeling code organized.
# - It bundles preprocessing and modeling steps so we can use the whole bundle in a single step.

# %%
ds = data.select_dtypes(include=[np.number])

# %%
ds
# Out:
#       Postal Code      Sales  Quantity  Discount     Profit
# 0           42420   261.9600         2      0.00    41.9136
# 1           42420   731.9400         3      0.00   219.5820
# 2           90036    14.6200         2      0.00     6.8714
# 3           33311   957.5775         5      0.45  -383.0310
# 4           33311    22.3680         2      0.20     2.5164
# 5           90032    48.8600         7      0.00    14.1694
# 6           90032     7.2800         4      0.00     1.9656
# 7           90032   907.1520         6      0.20    90.7152
# 8           90032    18.5040         3      0.20     5.7825
# 9           90032   114.9000         5      0.00    34.4700
# 10          90032  1706.1840         9      0.20    85.3092
# 11          90032   911.4240         4      0.20    68.3568
# 12          28027    15.5520         3      0.20     5.4432
# 13          98103   407.9760         3      0.20   132.5922
# 14          76106    68.8100         5      0.80  -123.8580
# ...

# %% [markdown]
# #### Checking for Outliers;
# - *We will use the box-plot feature of the seaborn library to detect the outliers clearly.*
# - A box plot (also known as box and whisker plot) is a type of chart often used in explanatory data analysis to visually show the distribution of numerical data and skewness through displaying the data quartiles (or percentiles) and averages.

# %%
# taking a list of all the features/columns
cols = ds.columns.tolist()

# Plotting the Box plot for all the features to identify outliers
for col in range(0, len(cols), 2):
  if len(cols) > col + 1:
    plt.figure(figsize=(10,4))
    plt.subplot(121)
    sns.boxplot(ds[cols[col]])
    plt.subplot(122)
    sns.boxplot(ds[cols[col + 1]])
    plt.tight_layout()
    plt.show()
  else:
    sns.boxplot(ds[cols[col]])

# %% [markdown]
# **Observation:**
# - From the above plot, the outliers in Sales and Profit are clearly seen.
# - As it has a large data set, we can remove those containing outliers to improve our results.¶

# %% [markdown]
# ### Removing Outliers

# %%
#importing the in-built winsorize model from scipy library
from scipy.stats.mstats import winsorize 

# Treating outliers by Winssorization
cols = list(ds)
for col in cols:
  if col in ds.select_dtypes(include=np.number).columns:
    ds[col] = winsorize(ds[col], limits=[0.05,0.1], inclusive=(True,True))

#Checking the data set shape again
ds.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (9977, 5)

# %%
# taking a list of all the features/columns
cols = ds.columns.tolist()

#Boxplot of all features to identify outliners
for col in range(0, len(cols), 2):
  if len(cols) > col + 1:
    plt.figure(figsize=(10,4))
    plt.subplot(121)
    sns.boxplot(ds[cols[col]])
    plt.subplot(122)
    sns.boxplot(ds[cols[col + 1]])
    plt.tight_layout()
    plt.show()
  else:
    sns.boxplot(ds[cols[col]])

# %% [markdown]
# *Here, above we can see out Winsorise model works pretty well and treated all the outliers with 100% accuracy.
# As we don't have any outliers and our data set is processed, it is ready for Exploratory Analysis*

# %%
ds.shape
# Out:
# (9977, 5)

# %%
ds.head()
# Out:
#    Postal Code    Sales  Quantity  Discount   Profit
# 0        42420  261.960         2       0.0  41.9136
# 1        42420  573.174         3       0.0  89.3142
# 2        90036   14.620         2       0.0   6.8714
# 3        33311  573.174         5       0.4 -53.2704
# 4        33311   22.368         2       0.2   2.5164

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 5 columns):
# Postal Code    9977 non-null int64
# Sales          9977 non-null float64
# Quantity       9977 non-null int64
# Discount       9977 non-null float64
# Profit         9977 non-null float64
# dtypes: float64(3), int64(2)
# memory usage: 787.7 KB

# %%
ds.describe()
# Out:
#         Postal Code        Sales     Quantity     Discount       Profit
# count   9977.000000  9977.000000  9977.000000  9977.000000  9977.000000
# mean   55129.312318   148.571288     3.634359     0.128239    17.431262
# std    31366.859837   186.521670     1.843141     0.137767    35.070270
# min    10009.000000     4.980000     1.000000     0.000000   -53.270400
# 25%    23223.000000    17.300000     2.000000     0.000000     1.726200
# 50%    55901.000000    54.816000     3.000000     0.200000     8.671000
# 75%    90008.000000   209.970000     5.000000     0.200000    29.372000
# max    94122.000000   573.174000     7.000000     0.400000    89.314200

# %% [markdown]
# ### Visualization

# %%
for i in data[['Ship Mode', 'Segment', 'Region', 'Category']]:
  plt.figure(figsize=(12,5))
  sns.countplot(data[i])
  plt.show()

# %% [markdown]
# **Observations:**
# - In the Ship mode, the Standard Class has the highest count which means the customers give the highest priority to this type of shipping mode.
# - In Segment, the Consumers have the highest count which means that the consumers use most of the shippings.
# - From the Regions graph, we observe that the West region has the highest customers count.
# - From the items category, we observe that the Office Supplies Category has the highest sales count.

# %% [markdown]
# ### Frequencies of the product's subcategories

# %%
plt.figure(figsize = (20,9))
sns.countplot(data['Sub-Category'])
plt.xticks(rotation=50, ha='right', fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Sub-Category', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Observation:** - From the above graph, we observe that some of the top sub-categories are Binders, Paper, Furnishings and Phones.

# %% [markdown]
# ### Top 15 Profittable selling products

# %%
top_15 = data.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by = 'Profit', ascending = False)
sns.catplot(x = 'Sub-Category', y = 'Profit', data = top_15.head(15), kind = 'bar', aspect = 2.5, palette = 'icefire')
plt.title('Top 15 Profitable Selling Products', fontsize = 15)
plt.xticks(rotation = 50, ha = 'right', fontsize = 15)
plt.yticks(fontsize = 15)
plt.ylabel('Profit', fontsize = 15)
plt.xlabel('Products', fontsize = 15)
# Out:
# Text(0.5, 8.91312499999998, 'Products')

# %% [markdown]
# From the above graph, we observe that some of the top most profitable selling products are Copiers, Phones, Accessories. We also observe that Machines have the lower count as well as profits, hence it is of least value. And Copiers gain higher profits despite having least count.

# %% [markdown]
# ### Sub-categories of selling products according to region

# %%
plt.figure(figsize = (30,12))
sns.countplot(x = 'Sub-Category', hue = 'Region', data = data, palette = 'vlag')
plt.xticks(rotation = 45, fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Sub-Categories', fontsize = 25) 
plt.ylabel('', fontsize = 20)
plt.legend(loc = 5, fontsize = 20)

# %% [markdown]
# **Observations** From the above graph, we can see that the top sub-categories according to region are Blinders, Paper, Furnishings. We also observe that the West region has higher count on an average.

# %% [markdown]
# ### Frequencies of sells of products in cities

# %%
plt.figure(figsize = (20,9))
sns.countplot(x = data['City'], order = (data['City'].value_counts().head(50)).index)
plt.xticks(rotation = 50, ha = 'right', fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('City', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Observations:**  We observe that the top sells are in cities like New York City, Los Angeles, Philadelphia.

# %% [markdown]
# ### Selecting top 15 states for above graph
# - To be more precise, we can get top 15 states for the above graph as shown below

# %%
top_15 = data.groupby('State')['Quantity'].sum().reset_index().sort_values(by = 'Quantity', ascending = False)
sns.catplot(x = 'State', y = 'Quantity', data = top_15.head(15), kind = 'bar', palette = 'vlag', aspect = 3)
plt.title('Top 15 States', fontsize = 15)
plt.xticks(rotation = 50, ha = 'right', fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('States', fontsize = 15)
plt.ylabel('Quantities ordered', fontsize = 15)
# Out:
# Text(-0.16500000000001336, 0.5, 'Quantities ordered')

# %% [markdown]
# **Observations:** We observe that the top selling states are California, New York, Texas

# %% [markdown]
# ### Combine the graph  regarding shipping modes and Segments

# %%
plt.figure(figsize = (30,12))
sns.countplot(x = 'Ship Mode', hue = 'Segment', data = data, palette = 'vlag')
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Shipping Modes', fontsize = 25)
plt.ylabel('', fontsize = 20)
plt.legend(loc = 5, fontsize = 20)

# %% [markdown]
# **Observations:** Here, we observe that the people prefer the standard class shipping mode and the items are mostly ordered by the consumer segment.

# %% [markdown]
# ## Visualization using PieChart

# %% [markdown]
# ### Quantities ordered by each region

# %%
df_region = data.groupby('Region')['Quantity'].sum().reset_index()
plt.figure(figsize = (15,10))
plt.pie(df_region['Quantity'], labels = df_region['Region'].unique(), autopct='%1.1f%%', startangle=90,
        colors = ['m', 'c', 'w', 'b'])
plt.title('Quantities ordered by each region', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by each region')

# %% [markdown]
# **Observations:** Here, From the above pie-chart, we can observe that the most number of quantities ordered, are from the West Region.

# %% [markdown]
# ### Average profit divided between different regions

# %%
df_region = data.groupby('Region')['Profit'].mean().reset_index()
plt.figure(figsize = (15,10))
plt.pie(df_region['Profit'], labels = df_region['Region'].unique(), autopct= '%.1f%%', startangle=90,
        colors = ['m', 'c', 'w', 'b'])
plt.title('Average profit divided between different regions', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Average profit divided between different regions')

# %% [markdown]
# **Observations:** The most number of profits are divided in the West Region.

# %% [markdown]
# ### Most Selling Categories

# %%
df_cat = data.groupby('Category')['Quantity'].sum().reset_index()
plt.figure(figsize = (15,10))
plt.pie(x = df_cat['Quantity'], labels = df_cat['Category'].unique(), autopct='%1.1f%%',
        colors = ['m', 'c', 'b'])
plt.title('Products sold according to category', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Products sold according to category')

# %% [markdown]
# **Observations:** We observe that the most number of sales are on the Office Supplies Category.

# %% [markdown]
# ### Different sub-categories ordered

# %%
plt.figure(figsize = (13,12))
plt.pie(x = data['Sub-Category'].value_counts(), labels = data['Sub-Category'].value_counts().index,
        colors = ['lightgrey', 'gold', 'lavender','lightseagreen', 'blue', 'azure', 'teal', 'pink', 'peru','cyan',
                  'bisque', 'forestgreen', 'slategrey', 'tan',  'darkorange', 'dimgray', 'lightsteelblue'                  ], autopct = '%1.1f%%',
        textprops = {'fontsize' : 12})
# Out:
# ([<matplotlib.patches.Wedge at 0x208dfdd3748>,
# ...
#  [Text(0.976073756684635, 0.5072277806977297, 'Binders'),
#   Text(0.2016538437473977, 1.081358278879808, 'Paper'),
#   Text(-0.5698750957020162, 0.9408731983102814, 'Furnishings'),
#   Text(-0.9927555531357746, 0.4737472023327234, 'Phones'),
#   Text(-1.0943856106501602, -0.1109961044445972, 'Storage'),
#   Text(-0.8966693479300548, -0.6371688006193416, 'Art'),
#   Text(-0.4869899755703049, -0.9863269050847361, 'Accessories'),
#   Text(-0.023032083622319597, -1.0997588477134497, 'Chairs'),
#   Text(0.3454481080284471, -1.044349369061698, 'Appliances'),
#   Text(0.6032749708252737, -0.9198148235246948, 'Labels'),
#   Text(0.7854334460362346, -0.7701261596956992, 'Tables'),
#   Text(0.9108832734856797, -0.6166779241095085, 'Envelopes'),
#   Text(0.9936488204365672, -0.47187076794925403, 'Bookcases'),
#   Text(1.0498137341525071, -0.32846784254287287, 'Fasteners'),
#   Text(1.0831847727456425, -0.19160049084480674, 'Supplies'),
# ...

# %% [markdown]
# **Observations** We observe the different sub-categories ordered by their percentages of quantites. Here, we have added colors in each category to make it more visually appealing and the pie-chart more understandable.

# %% [markdown]
# ### Conclusion
# - From the above all the observations and visualizations from the given data set, the business owner can understand the weak areas where he can work to gain more profits.
